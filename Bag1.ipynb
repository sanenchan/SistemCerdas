# %% [markdown]
# <a href="https://colab.research.google.com/github/sanenchan/SistemCerdas/blob/main/Bag1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob
import csv

# %%
consumer_key = 'O7H8dzerkUi1rfoc1Yf0n27GV'
consumer_secret = 'W8E6SPzBi76SWSAh1FhbpiFNx0TW8jLLv5FU26UAtcR3hGZ8V7'
access_token = '89192651-szUXRV8wGlgYL6E0OemwrG9GRgY0OvAI0mhMUpcq4'
access_token_secret = '0rM14tIfe1mCz7EboOtGRxhN6ep64UMrC8P4h48TDdzU9'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
public_tweets = api.search(q=['ovo', 'gopay'], count=50)

# %%
all_polarity = 0 
for tweet in public_tweets:
  print(tweet.text)
  #step 3 perform sentiment analist on tweets
  analysis = TextBlob(tweet.text)
  an = analysis.translate(from_lang='id', to='en')
  print(an.sentiment)
  all_polarity += an.polarity
  print("")
# Out:
# ‼️ PROMO NETFLIX ANTIHOLD‼️
#
# ⚠️ ONLY 27K ⚠️
#
# 🍃READY FRESH BILL🍃
# TF LANGSUNG DPT AKUN
#
# 📌SHARING / 1 PROFIL:… https://t.co/KXXdmyIyf0
# Sentiment(polarity=0.14545454545454545, subjectivity=0.6666666666666666)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# ‼️ PROMO NETFLIX ANTIHOLD‼️
#
# ⚠️ ONLY 27K ⚠️
#
# 🍃READY FRESH BILL🍃
# TF LANGSUNG DPT AKUN
#
# 📌SHARING / 1 PROFIL:… https://t.co/Q9GPGFScBz
# Sentiment(polarity=0.14545454545454545, subjectivity=0.6666666666666666)
#
# ‼️ PROMO NETFLIX ANTIHOLD‼️
#
# ⚠️ ONLY 27K ⚠️
#
# 🍃READY FRESH BILL🍃
# TF LANGSUNG DPT AKUN
#
# 📌SHARING / 1 PROFIL:… https://t.co/ke3HUZcUuZ
# Sentiment(polarity=0.14545454545454545, subjectivity=0.6666666666666666)
#
# ‼️ PROMO NETFLIX ANTIHOLD‼️
#
# ⚠️ ONLY 27K ⚠️
#
# 🍃READY FRESH BILL🍃
# TF LANGSUNG DPT AKUN
#
# 📌SHARING / 1 PROFIL:… https://t.co/JhNmFfZkoL
# Sentiment(polarity=0.14545454545454545, subjectivity=0.6666666666666666)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @moonaespa: Karena Aespa debut hari ini, aku mau GA saldo e wallet (dana/gopay/pulsa/ovo) buat 4 orang pemenang (25k/orang). Syaratnya:…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# @rizkyarfian @CutiesLollipoop ••••JUAL SPOTIFY PREMIUM••••
#
# aktivasi / perpanjang
# 💸13k/bulan
# 💸18k/2bulan
# 💸25k/3bula… https://t.co/2gtMly8IwQ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Eunsobie ••••JUAL SPOTIFY PREMIUM••••
#
# aktivasi / perpanjang
# 💸13k/bulan
# 💸18k/2bulan
# 💸25k/3bulan
#
# 🍭legal &amp; bergaran… https://t.co/XUkzKpHwjE
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# @mm34nismind ••••JUAL SPOTIFY PREMIUM••••
#
# aktivasi / perpanjang
# 💸13k/bulan
# 💸18k/2bulan
# 💸25k/3bulan
#
# 🍭legal &amp; berga… https://t.co/VZ4fj8aPDd
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# Anda juga berkesempatan mendapatkan reward berupa saldo OVO/GoPay dengan total sebesar Rp100.000.
#
# Jika Anda memil… https://t.co/KWsfkEkZVv
# Sentiment(polarity=0.0, subjectivity=0.75)
#
# RT @hopanacea: FAST GA SYUKURAN LIFE GOES ON #1 BB HOT 100, BE #1 BB 200, BTS BILLBOARD ALL-KILL
#
# pulsa/dana/ovo/gopay
# untuk 7 orang @ 25k…
# Sentiment(polarity=0.225, subjectivity=0.7250000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# @lavienmaze Viu 1 tahun 18k
# netflix sharing 25k
# netflix sharing 3 bulan 95k
#
# order dm or https://t.co/sUY6vy1jUO
# pa… https://t.co/xYrkfKJUIG
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @lavienmaze REEEPPP
#
# ✨ WELCOME DECEMBER ✨
#
# NETFLIX:
# ❗SHARING: 35K/BLN❗
# ❗PRIVATE: 12OK/BLN❗
#
# FULL GARANSI, TRUSTED,… https://t.co/ym1q42jJQA
# Sentiment(polarity=0.575, subjectivity=0.7250000000000001)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# Apabila Anda memenuhi kriteria berikut:
# 1. Mahasiswa Aktif Program DIII atau S1 Universitas Indonesia.
# 2. Pernah me… https://t.co/8I8l1sc2Yv
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.35)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# @MuhamadFaisal77 @FiersaBesari ✨ NETFLIX ANTI ON HOLD ✨
#
# 🌻 SHARING (1 USER)     25K
# 🌻 PRIVATE (4-5 USER) 120K
#
# TF L… https://t.co/lL6gFqerJ0
# Sentiment(polarity=0.0, subjectivity=0.375)
#
# @Headdyy_ HADIIIR
#
# ✨ WELCOME DECEMBER ✨
#
# NETFLIX:
# ❗SHARING: 35K/BLN❗
# ❗PRIVATE: 12OK/BLN❗
#
# FULL GARANSI, TRUSTED, AM… https://t.co/Ec0AW4Sd8K
# Sentiment(polarity=0.575, subjectivity=0.7250000000000001)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# 765. convert/ cv ke dana
# 766. convert/ cv ke ovo
# 767. convert/ cv ke gopay
# 768. convert/ cv ke ovo https://t.co/Bo4JeJSUuC
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @jumintensbybaru: Gass yukk📢📢📢
#
# 10K (shopeepay/ovo/gopay)
# RT dan follow aku
# Tag temen juga boleh
#
# End Dadakan
#
# 🎉 goodluck everyone 🎉
# Sentiment(polarity=0.25, subjectivity=0.5)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# @lavienmaze ✨ NETFLIX ANTI ON HOLD ✨
#
# 🌻 SHARING (1 USER)     25K
# 🌻 PRIVATE (4-5 USER) 120K
#
# TF LANGSUNG DAPAT AKUN… https://t.co/PBCVhcfsit
# Sentiment(polarity=0.05, subjectivity=0.3875)
#
# RT @jumintensbybaru: Gass yukk📢📢📢
#
# 10K (shopeepay/ovo/gopay)
# RT dan follow aku
# Tag temen juga boleh
#
# End Dadakan
#
# 🎉 goodluck everyone 🎉
# Sentiment(polarity=0.25, subjectivity=0.5)
#
# @Headdyy_ ✨ NETFLIX ANTI ON HOLD ✨
#
# 🌻 SHARING (1 USER)     25K
# 🌻 PRIVATE (4-5 USER) 120K
#
# TF LANGSUNG DAPAT AKUN
# ❗❗… https://t.co/S12udwhFsJ
# Sentiment(polarity=0.05, subjectivity=0.3875)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)

# %%
#step 4
if (all_polarity/100>0):
  print(all_polarity/100)
  print("")
  print('Positive')
else:
  print(all_polarity/100)
  print("")
  print("Negative")
# Out:
# 0.09790151515151516
#
# Positive
