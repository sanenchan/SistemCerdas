# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
#P=[2,4,4,4,5,5,7,9]
P=np.arange(-10,10,0.001)

# %%
#plt.hist(P)
#plt.title("histogram")
#std = np.std(P)
#mean= np.mean(P)
#plt.plot(norm.pdf(P,mean,std))
plt.plot(P,norm.pdf(P,0,2))
plt.grid()
plt.show()
